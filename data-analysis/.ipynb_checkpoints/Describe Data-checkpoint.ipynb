# %%
# %run 'Setup.ipynb'

# %% [markdown]
# # Describe Data on difference criteria

# %% [markdown]
# ##  Describe All Data on Different Framework

# %%
describe_data(lambda x: x)
# Out:
# <style type="text/css">
# </style>
# <table id="T_44f6b_" style='display:inline'>
#   <caption>Django</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >new_order</th>
#       <th class="col_heading level0 col1" >payment</th>
#       <th class="col_heading level0 col2" >order_status</th>
#       <th class="col_heading level0 col3" >delivery</th>
#       <th class="col_heading level0 col4" >stock_level</th>
#       <th class="col_heading level0 col5" >total_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44f6b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_44f6b_row0_col0" class="data row0 col0" >1100.000000</td>
#       <td id="T_44f6b_row0_col1" class="data row0 col1" >1100.000000</td>
#       <td id="T_44f6b_row0_col2" class="data row0 col2" >1100.000000</td>
#       <td id="T_44f6b_row0_col3" class="data row0 col3" >1100.000000</td>
# ...

# %% [markdown]
# ##  Describe Data on Difference in CPU

# %%
describe_data(difference_cpu)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e7d2e_" style='display:inline'>
#   <caption>Django</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >new_order</th>
#       <th class="col_heading level0 col1" >payment</th>
#       <th class="col_heading level0 col2" >order_status</th>
#       <th class="col_heading level0 col3" >delivery</th>
#       <th class="col_heading level0 col4" >stock_level</th>
#       <th class="col_heading level0 col5" >total_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7d2e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_e7d2e_row0_col0" class="data row0 col0" >400.000000</td>
#       <td id="T_e7d2e_row0_col1" class="data row0 col1" >400.000000</td>
#       <td id="T_e7d2e_row0_col2" class="data row0 col2" >400.000000</td>
#       <td id="T_e7d2e_row0_col3" class="data row0 col3" >400.000000</td>
# ...

# %% [markdown]
# ##  Describe Data on Difference in RAM

# %%
describe_data(difference_ram)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0efd3_" style='display:inline'>
#   <caption>Django</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >new_order</th>
#       <th class="col_heading level0 col1" >payment</th>
#       <th class="col_heading level0 col2" >order_status</th>
#       <th class="col_heading level0 col3" >delivery</th>
#       <th class="col_heading level0 col4" >stock_level</th>
#       <th class="col_heading level0 col5" >total_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0efd3_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_0efd3_row0_col0" class="data row0 col0" >300.000000</td>
#       <td id="T_0efd3_row0_col1" class="data row0 col1" >300.000000</td>
#       <td id="T_0efd3_row0_col2" class="data row0 col2" >300.000000</td>
#       <td id="T_0efd3_row0_col3" class="data row0 col3" >300.000000</td>
# ...

# %% [markdown]
# ##  Describe Data on Difference in Warehouse

# %%
describe_data(default_setup)
# Out:
# <style type="text/css">
# </style>
# <table id="T_98610_" style='display:inline'>
#   <caption>Django</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >new_order</th>
#       <th class="col_heading level0 col1" >payment</th>
#       <th class="col_heading level0 col2" >order_status</th>
#       <th class="col_heading level0 col3" >delivery</th>
#       <th class="col_heading level0 col4" >stock_level</th>
#       <th class="col_heading level0 col5" >total_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98610_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_98610_row0_col0" class="data row0 col0" >600.000000</td>
#       <td id="T_98610_row0_col1" class="data row0 col1" >600.000000</td>
#       <td id="T_98610_row0_col2" class="data row0 col2" >600.000000</td>
#       <td id="T_98610_row0_col3" class="data row0 col3" >600.000000</td>
# ...
