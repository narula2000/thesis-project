# %%
# %run 'Setup.ipynb'

# %% [markdown]
# # Plot Difference in CPU

# %% [markdown]
# ## Plot Latency

# %%
plot_latency('cpu', difference_cpu)
plot_framework_latency('cpu', difference_cpu)

# %%
plot_framework_latency_pair_js_rust('cpu', difference_cpu)

# %% [markdown]
# ## Plot Throughput

# %%
plot_throughput('cpu', difference_cpu)
plot_framework_throughput('cpu', difference_cpu)

# %%
plot_framework_throughput_pair_js_rust('cpu', difference_cpu)
