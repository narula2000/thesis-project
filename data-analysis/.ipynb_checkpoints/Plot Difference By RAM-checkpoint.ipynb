# %%
# %run 'Setup.ipynb'

# %% [markdown]
# # Plot Difference in RAM

# %% [markdown]
# ## Plot Latency

# %%
plot_latency('ram', difference_ram)
plot_framework_latency('ram', difference_ram)

# %% [markdown]
# ## Plot Throughput

# %%
plot_throughput('ram', difference_ram)
plot_framework_throughput('ram', difference_ram)
